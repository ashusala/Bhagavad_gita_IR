# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import unidecode

# %%
# setting up our chrome webdriver
driver = webdriver.Chrome("/usr/local/bin/chromedriver")

# setting up the url and creating the content soup
fixed_url = "https://vedabase.io/en/library/lob/"

# %%
# getting the texts

# a list to contain all the texts
texts = []

# looping over all the pages 
for i in range(1,49):

    url = fixed_url + str(i) + '/'
    driver.get(url)
    content = driver.page_source
    soup = BeautifulSoup(content).find('div', attrs={'id':'content'})
    
    # getting all tha paras
    for text in soup.find_all('div', attrs={'class':'rich-text'}):
        if text.find('p') != None:
            texts.append(unidecode.unidecode(text.find('p').text))
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
# just to check if everything worked out okay... :)
texts
print(len(texts))
print(texts[197])
# Out:
# 198
# ...

# %%
with open("light-of-the-bhagvata.txt", 'w+') as f:
    for text in texts:
        f.write(str(text) + ' ')
